# %% [markdown]
# <a href="https://colab.research.google.com/github/zunaed/CS_687_DeepLearningCourse/blob/main/LSTM_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
from keras.models import Sequential
from keras.layers import LSTM ,Dense, Dropout
from tensorflow.keras.optimizers import SGD

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_path = "/content/drive/MyDrive/UCI_HAR_Dataset/train/"
test_path = "/content/drive/MyDrive/UCI_HAR_Dataset/test/"
features_path = "/content/drive/MyDrive/UCI_HAR_Dataset/features.txt"

# %%
features = []
with open(features_path) as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
print("No. of unique features:{}".format(len(set(features))))
# Out:
# No of Features: 561
# No. of unique features:477

# %%
labels = {1: 'WALKING', 
          2:'WALKING_UPSTAIRS',
          3:'WALKING_DOWNSTAIRS',
          4:'SITTING',
          5:'STANDING',
          6:'LAYING'}

# %%
re=[]
for i , f in enumerate(features):
    for j in range(i+1 , len(features)):
        if features[i]==features[j] and features[i] not in re:
            re.append(features[i])

# %%
for i , f in enumerate(features):
    features[i] = ''.join(e for e in f if e not in ['(',')' , '-' , ','])

# %%
train = pd.read_csv(train_path + "X_train.txt" , delim_whitespace=True ,header=None)
train.columns = features
train['subject'] = pd.read_csv(train_path + 'subject_train.txt' , header=None , squeeze=True)
test = pd.read_csv(test_path + "X_test.txt" , delim_whitespace=True ,header=None)
test.columns = features
test['subject'] = pd.read_csv(test_path + 'subject_test.txt' , header=None , squeeze=True)

# %%
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    fBodyBodyGyroJerkMagskewness  fBodyBodyGyroJerkMagkurtosis  \
# 0                     -0.298676                     -0.710304
# 1                     -0.595051                     -0.861499
# 2                     -0.390748                     -0.760104
# 3                     -0.117290                     -0.482845
# 4                     -0.351471                     -0.699205
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
# 3                 -0.036788                         -0.012892
# 4                  0.123320                          0.122542
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
# 3                       0.640011                          -0.485366
# 4                       0.693578                          -0.615971
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject
# 0          -0.841247           0.179941          -0.058627        1
# 1          -0.844788           0.180289          -0.054317        1
# 2          -0.848933           0.180637          -0.049118        1
# 3          -0.848649           0.181935          -0.047663        1
# 4          -0.847865           0.185151          -0.043892        1
#
# [5 rows x 562 columns]

# %%
test.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1       0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2       0.275485      -0.026050      -0.118152     -0.993819     -0.969926
# 3       0.270298      -0.032614      -0.117520     -0.994743     -0.973268
# 4       0.274833      -0.027848      -0.129527     -0.993852     -0.967445
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.667683     -0.952501     -0.925249     -0.674302     -0.894088  ...
# 1     -0.944958     -0.986799     -0.968401     -0.945823     -0.894088  ...
# 2     -0.962748     -0.994403     -0.970735     -0.963483     -0.939260  ...
# 3     -0.967091     -0.995274     -0.974471     -0.968897     -0.938610  ...
# 4     -0.978295     -0.994111     -0.965953     -0.977346     -0.938610  ...
#
#    fBodyBodyGyroJerkMagskewness  fBodyBodyGyroJerkMagkurtosis  \
# 0                     -0.330370                     -0.705974
# 1                     -0.121845                     -0.594944
# 2                     -0.190422                     -0.640736
# 3                     -0.344418                     -0.736124
# 4                     -0.534685                     -0.846595
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                  0.006462                          0.162920
# 1                 -0.083495                          0.017500
# 2                 -0.034956                          0.202302
# 3                 -0.017067                          0.154438
# 4                 -0.002223                         -0.040046
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.825886                           0.271151
# 1                      -0.434375                           0.920593
# 2                       0.064103                           0.145068
# 3                       0.340134                           0.296407
# 4                       0.736715                          -0.118545
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject
# 0          -0.720009           0.276801          -0.057978        2
# 1          -0.698091           0.281343          -0.083898        2
# 2          -0.702771           0.280083          -0.079346        2
# 3          -0.698954           0.284114          -0.077108        2
# 4          -0.692245           0.290722          -0.073857        2
#
# [5 rows x 562 columns]

# %%
y_train = pd.read_csv(train_path + 'y_train.txt' , names=['Activity'] , squeeze=True)
y_test = pd.read_csv(test_path + 'y_test.txt' , names=['Activity'] , squeeze=True)

# %%
train['Activity']= y_train
test['Activity'] = y_test
train['ActivityName'] = y_train.map(labels)
test['ActivityName']  = y_test.map(labels)

# %%
print("The number of missing values in Training Data:" , train.isnull().values.sum())
print("The number of missing values in Testing Data:" , test.isnull().values.sum())
# Out:
# The number of missing values in Training Data: 0
# The number of missing values in Testing Data: 0

# %%
print("The number of duplicate values in Training Data:" , train.duplicated().sum())
print("The number of duplicate values in Testing Data:" , test.duplicated().sum())
# Out:
# The number of duplicate values in Training Data: 0
# The number of duplicate values in Testing Data: 0

# %%
plt.figure(figsize=(10,5))
plt.title('Subject Wise Data Distribution')
sns.countplot(x='subject' , data=train )
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.title('Activity based Subject Distribution')
sns.countplot(x='subject' , hue='ActivityName', data=train )
plt.show()

# %%
accFeat=[]
for feat in features:
    if feat.find('BodyAcc') != -1 and feat.find('Magmean') !=-1 and feat.find('Freq')==-1:
        accFeat.append(feat)

# %%
def plotFacetGrid(feature, height):
    
    plt.figure(figsize=(10,10))
    facetgrid=sns.FacetGrid(train , hue='ActivityName',height=height,aspect=3)
    facetgrid.map(sns.distplot ,feature, hist=False).add_legend()
    plt.show()

# %%
for f in accFeat:
    plotFacetGrid(f,3)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
def boxplot(feature , ylabel):
    
    plt.figure(figsize=(5,5))
    sns.boxplot(x='ActivityName', y=feature, data=train , showfliers=False )
    plt.ylabel(ylabel)
    plt.axhline(y=-0.8, xmin=0.1, xmax=0.9,dashes=(5,5), c='g') #line separating both type of activities
    plt.xticks(rotation=90)

# %%
for f in accFeat:
    boxplot(f , f[5:])

# %%
from sklearn.manifold import TSNE

# %%
def plotTsne(X,y,perplexity):
    
    #performing dim reduction
    X_reduce = TSNE(verbose=2, perplexity=perplexity).fit_transform(X)
    
    print('Creating plot for this t-sne visualization..')
    data={'x':X_reduce[:,0],
          'y':X_reduce[:,1],
         'label':y}
    #preparing dataframe from reduced data
    df = pd.DataFrame(data)
    
    #draw the plot
    sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
    
    plt.title("perplexity : {}".format(perplexity))
    img_name = 'TSNE_perp_{}.png'.format(perplexity)
    print('saving this plot as image in present working directory...')
    plt.savefig(img_name)
    plt.show()
    print('Done')

# %%
X= train.drop(['ActivityName'],axis=1)
y= train['ActivityName']
perplexity=[2,5,10]

# %%
for p in perplexity:
    plotTsne(X,y,perplexity=p)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# [t-SNE] Computed neighbors for 7352 samples in 2.027s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.685862
# [t-SNE] Computed conditional probabilities in 0.038s
# [t-SNE] Iteration 50: error = 124.7996521, gradient norm = 0.0355348 (50 iterations in 3.332s)
# [t-SNE] Iteration 100: error = 104.8479614, gradient norm = 0.0320243 (50 iterations in 2.075s)
# [t-SNE] Iteration 150: error = 98.1376038, gradient norm = 0.0239798 (50 iterations in 1.668s)
# [t-SNE] Iteration 200: error = 94.2239532, gradient norm = 0.0198471 (50 iterations in 1.609s)
# [t-SNE] Iteration 250: error = 91.4967041, gradient norm = 0.0143790 (50 iterations in 1.608s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 91.496704
# [t-SNE] Iteration 300: error = 4.0041761, gradient norm = 0.0015559 (50 iterations in 1.674s)
# [t-SNE] Iteration 350: error = 3.0941672, gradient norm = 0.0010071 (50 iterations in 1.815s)
# [t-SNE] Iteration 400: error = 2.6589847, gradient norm = 0.0007238 (50 iterations in 1.841s)
# [t-SNE] Iteration 450: error = 2.3906446, gradient norm = 0.0005689 (50 iterations in 1.858s)
# [t-SNE] Iteration 500: error = 2.2035406, gradient norm = 0.0004761 (50 iterations in 1.913s)
# [t-SNE] Iteration 550: error = 2.0622125, gradient norm = 0.0004218 (50 iterations in 1.892s)
# [t-SNE] Iteration 600: error = 1.9498949, gradient norm = 0.0003725 (50 iterations in 1.935s)
# [t-SNE] Iteration 650: error = 1.8578544, gradient norm = 0.0003384 (50 iterations in 1.877s)
# [t-SNE] Iteration 700: error = 1.7801883, gradient norm = 0.0003074 (50 iterations in 1.906s)
# [t-SNE] Iteration 750: error = 1.7135589, gradient norm = 0.0002794 (50 iterations in 1.926s)
# [t-SNE] Iteration 800: error = 1.6553073, gradient norm = 0.0002609 (50 iterations in 1.894s)
# [t-SNE] Iteration 850: error = 1.6039606, gradient norm = 0.0002388 (50 iterations in 1.891s)
# [t-SNE] Iteration 900: error = 1.5579431, gradient norm = 0.0002284 (50 iterations in 1.928s)
# [t-SNE] Iteration 950: error = 1.5167933, gradient norm = 0.0002146 (50 iterations in 1.915s)
# [t-SNE] Iteration 1000: error = 1.4792714, gradient norm = 0.0002014 (50 iterations in 1.891s)
# [t-SNE] KL divergence after 1000 iterations: 1.479271
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 7352 samples in 1.789s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.127762
# [t-SNE] Computed conditional probabilities in 0.062s
# [t-SNE] Iteration 50: error = 112.9105148, gradient norm = 0.0399115 (50 iterations in 3.330s)
# [t-SNE] Iteration 100: error = 92.9826508, gradient norm = 0.0186935 (50 iterations in 1.944s)
# [t-SNE] Iteration 150: error = 86.9125671, gradient norm = 0.0140200 (50 iterations in 1.632s)
# [t-SNE] Iteration 200: error = 83.5613708, gradient norm = 0.0102263 (50 iterations in 1.636s)
# [t-SNE] Iteration 250: error = 81.3217163, gradient norm = 0.0091045 (50 iterations in 1.659s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.321716
# [t-SNE] Iteration 300: error = 3.2649238, gradient norm = 0.0014418 (50 iterations in 1.734s)
# [t-SNE] Iteration 350: error = 2.4972110, gradient norm = 0.0007615 (50 iterations in 1.767s)
# [t-SNE] Iteration 400: error = 2.1049225, gradient norm = 0.0005352 (50 iterations in 1.893s)
# [t-SNE] Iteration 450: error = 1.8805985, gradient norm = 0.0004140 (50 iterations in 1.869s)
# [t-SNE] Iteration 500: error = 1.7317430, gradient norm = 0.0003387 (50 iterations in 1.902s)
# [t-SNE] Iteration 550: error = 1.6231849, gradient norm = 0.0002888 (50 iterations in 1.903s)
# [t-SNE] Iteration 600: error = 1.5399032, gradient norm = 0.0002514 (50 iterations in 1.963s)
# [t-SNE] Iteration 650: error = 1.4729438, gradient norm = 0.0002254 (50 iterations in 1.894s)
# [t-SNE] Iteration 700: error = 1.4174842, gradient norm = 0.0002008 (50 iterations in 1.892s)
# [t-SNE] Iteration 750: error = 1.3703637, gradient norm = 0.0001847 (50 iterations in 1.885s)
# [t-SNE] Iteration 800: error = 1.3299429, gradient norm = 0.0001720 (50 iterations in 1.892s)
# [t-SNE] Iteration 850: error = 1.2948134, gradient norm = 0.0001580 (50 iterations in 1.886s)
# [t-SNE] Iteration 900: error = 1.2634655, gradient norm = 0.0001494 (50 iterations in 1.912s)
# [t-SNE] Iteration 950: error = 1.2356949, gradient norm = 0.0001397 (50 iterations in 1.901s)
# [t-SNE] Iteration 1000: error = 1.2106493, gradient norm = 0.0001305 (50 iterations in 1.891s)
# [t-SNE] KL divergence after 1000 iterations: 1.210649
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computed neighbors for 7352 samples in 1.768s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.357802
# [t-SNE] Computed conditional probabilities in 0.112s
# [t-SNE] Iteration 50: error = 103.4567795, gradient norm = 0.0348582 (50 iterations in 3.052s)
# [t-SNE] Iteration 100: error = 84.0838318, gradient norm = 0.0135784 (50 iterations in 1.969s)
# [t-SNE] Iteration 150: error = 78.9202271, gradient norm = 0.0090706 (50 iterations in 1.747s)
# [t-SNE] Iteration 200: error = 76.0754547, gradient norm = 0.0075073 (50 iterations in 1.696s)
# [t-SNE] Iteration 250: error = 74.2353668, gradient norm = 0.0055397 (50 iterations in 1.693s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.235367
# [t-SNE] Iteration 300: error = 2.7214756, gradient norm = 0.0013902 (50 iterations in 1.778s)
# [t-SNE] Iteration 350: error = 2.0558829, gradient norm = 0.0006668 (50 iterations in 1.864s)
# [t-SNE] Iteration 400: error = 1.7145437, gradient norm = 0.0004373 (50 iterations in 1.887s)
# [t-SNE] Iteration 450: error = 1.5198667, gradient norm = 0.0003209 (50 iterations in 1.901s)
# [t-SNE] Iteration 500: error = 1.3959885, gradient norm = 0.0002596 (50 iterations in 1.928s)
# [t-SNE] Iteration 550: error = 1.3091277, gradient norm = 0.0002171 (50 iterations in 1.941s)
# [t-SNE] Iteration 600: error = 1.2441911, gradient norm = 0.0001876 (50 iterations in 1.954s)
# [t-SNE] Iteration 650: error = 1.1933556, gradient norm = 0.0001642 (50 iterations in 1.923s)
# [t-SNE] Iteration 700: error = 1.1522769, gradient norm = 0.0001482 (50 iterations in 1.945s)
# [t-SNE] Iteration 750: error = 1.1183414, gradient norm = 0.0001349 (50 iterations in 1.949s)
# [t-SNE] Iteration 800: error = 1.0895703, gradient norm = 0.0001248 (50 iterations in 1.927s)
# [t-SNE] Iteration 850: error = 1.0653849, gradient norm = 0.0001151 (50 iterations in 1.940s)
# [t-SNE] Iteration 900: error = 1.0444087, gradient norm = 0.0001110 (50 iterations in 1.975s)
# [t-SNE] Iteration 950: error = 1.0260745, gradient norm = 0.0001062 (50 iterations in 1.914s)
# [t-SNE] Iteration 1000: error = 1.0103413, gradient norm = 0.0000990 (50 iterations in 1.934s)
# [t-SNE] KL divergence after 1000 iterations: 1.010341
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %%
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

# %%
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
path= "/content/drive/MyDrive/UCI_HAR_Dataset/"

# %%
# Utility function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

"----------------------------LOAD SIGNAL---------------------------------------------"

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = path+subset+'/Inertial Signals/'+signal+'_'+subset+'.txt'
        signals_data.append(
            _read_csv(filename).values
        ) 

    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

# %%
"-------------------------CONFUSION MATRIX----------------------------------------------"

# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])

# %%
"----------------------------LOAD Y-------------------------------------------------------"



def load_y(subset):
    """
    The objective that we are trying to predict is a integer, from 1 to 6,
    that represents a human activity. We return a binary representation of 
    every sample objective as a 6 bits vector using One Hot Encoding
    (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
    """
    filename = path+subset+'/y_'+subset+'.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).values

# %%
"---------------------------------LOAD DATA---------------------------------------------"


def load_data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, X_test, y_train, y_test

# %%
"---------------------------------COUNT CLASSES--------------------------------------------"

# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
epochs = 50
batch_size = 16
n_hidden = 32

# %%
X_train, X_test, Y_train, Y_test = load_data()

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
# Out:
# 128
# 9
# 7352

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
#model.add(Dropout(0.5))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid')) 
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 32)                5376
#
#  dense_3 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy']) #rmsprop

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='LSTMmodel.png', show_shapes=True, show_layer_names=True)

# %%
history=model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=epochs)
# Out:
# Epoch 1/50
# 460/460 [==============================] - 27s 52ms/step - loss: 1.1265 - accuracy: 0.5340 - val_loss: 1.3946 - val_accuracy: 0.5317
# Epoch 2/50
# 460/460 [==============================] - 23s 51ms/step - loss: 0.6750 - accuracy: 0.7394 - val_loss: 0.6832 - val_accuracy: 0.7520
# Epoch 3/50
# 460/460 [==============================] - 23s 51ms/step - loss: 0.4954 - accuracy: 0.8258 - val_loss: 0.5816 - val_accuracy: 0.8127
# Epoch 4/50
# 460/460 [==============================] - 25s 55ms/step - loss: 0.3520 - accuracy: 0.8822 - val_loss: 0.5149 - val_accuracy: 0.8426
# Epoch 5/50
# 460/460 [==============================] - 23s 51ms/step - loss: 0.2722 - accuracy: 0.9095 - val_loss: 0.4320 - val_accuracy: 0.8585
# Epoch 6/50
# 460/460 [==============================] - 23s 51ms/step - loss: 0.2178 - accuracy: 0.9234 - val_loss: 0.4050 - val_accuracy: 0.8558
# Epoch 7/50
# 460/460 [==============================] - 24s 52ms/step - loss: 0.1982 - accuracy: 0.9279 - val_loss: 0.3991 - val_accuracy: 0.8700
# Epoch 8/50
# 460/460 [==============================] - 24s 52ms/step - loss: 0.2193 - accuracy: 0.9257 - val_loss: 0.3493 - val_accuracy: 0.8775
# Epoch 9/50
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1819 - accuracy: 0.9378 - val_loss: 0.3354 - val_accuracy: 0.8870
# Epoch 10/50
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1466 - accuracy: 0.9448 - val_loss: 0.3579 - val_accuracy: 0.8765
# Epoch 11/50
# 460/460 [==============================] - 23s 49ms/step - loss: 0.4099 - accuracy: 0.8720 - val_loss: 0.4840 - val_accuracy: 0.8337
# Epoch 12/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.2044 - accuracy: 0.9286 - val_loss: 0.3385 - val_accuracy: 0.8890
# Epoch 13/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.2415 - accuracy: 0.9124 - val_loss: 0.4022 - val_accuracy: 0.8809
# Epoch 14/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1776 - accuracy: 0.9366 - val_loss: 0.3592 - val_accuracy: 0.8795
# Epoch 15/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1470 - accuracy: 0.9461 - val_loss: 0.3671 - val_accuracy: 0.8846
# Epoch 16/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1384 - accuracy: 0.9482 - val_loss: 0.3736 - val_accuracy: 0.8880
# Epoch 17/50
# 460/460 [==============================] - 21s 47ms/step - loss: 0.1532 - accuracy: 0.9385 - val_loss: 0.3718 - val_accuracy: 0.8877
# Epoch 18/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1455 - accuracy: 0.9438 - val_loss: 0.3271 - val_accuracy: 0.9026
# Epoch 19/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1477 - accuracy: 0.9403 - val_loss: 0.2886 - val_accuracy: 0.8924
# Epoch 20/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1566 - accuracy: 0.9370 - val_loss: 0.3880 - val_accuracy: 0.8741
# Epoch 21/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1316 - accuracy: 0.9480 - val_loss: 0.2940 - val_accuracy: 0.9009
# Epoch 22/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1271 - accuracy: 0.9476 - val_loss: 0.3676 - val_accuracy: 0.8921
# Epoch 23/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1370 - accuracy: 0.9425 - val_loss: 0.3318 - val_accuracy: 0.9019
# Epoch 24/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1313 - accuracy: 0.9450 - val_loss: 0.3104 - val_accuracy: 0.8945
# Epoch 25/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1416 - accuracy: 0.9441 - val_loss: 0.3191 - val_accuracy: 0.9091
# Epoch 26/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1284 - accuracy: 0.9482 - val_loss: 0.2914 - val_accuracy: 0.9019
# Epoch 27/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1249 - accuracy: 0.9521 - val_loss: 0.2821 - val_accuracy: 0.9145
# Epoch 28/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1203 - accuracy: 0.9501 - val_loss: 0.4751 - val_accuracy: 0.8633
# Epoch 29/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1513 - accuracy: 0.9436 - val_loss: 0.4100 - val_accuracy: 0.8741
# Epoch 30/50
# 460/460 [==============================] - 23s 49ms/step - loss: 0.1292 - accuracy: 0.9494 - val_loss: 0.4125 - val_accuracy: 0.8884
# Epoch 31/50
# 460/460 [==============================] - 23s 49ms/step - loss: 0.1137 - accuracy: 0.9535 - val_loss: 0.3451 - val_accuracy: 0.8945
# Epoch 32/50
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1070 - accuracy: 0.9557 - val_loss: 0.3246 - val_accuracy: 0.9172
# Epoch 33/50
# 460/460 [==============================] - 23s 49ms/step - loss: 0.1249 - accuracy: 0.9489 - val_loss: 0.2837 - val_accuracy: 0.9128
# Epoch 34/50
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1123 - accuracy: 0.9550 - val_loss: 0.2792 - val_accuracy: 0.9158
# Epoch 35/50
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1070 - accuracy: 0.9528 - val_loss: 0.2955 - val_accuracy: 0.9189
# Epoch 36/50
# 460/460 [==============================] - 23s 49ms/step - loss: 0.1159 - accuracy: 0.9514 - val_loss: 0.2643 - val_accuracy: 0.9179
# Epoch 37/50
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1084 - accuracy: 0.9553 - val_loss: 0.2907 - val_accuracy: 0.9206
# Epoch 38/50
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1079 - accuracy: 0.9532 - val_loss: 0.3071 - val_accuracy: 0.9063
# Epoch 39/50
# 460/460 [==============================] - 23s 49ms/step - loss: 0.1074 - accuracy: 0.9558 - val_loss: 0.3731 - val_accuracy: 0.9067
# Epoch 40/50
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1622 - accuracy: 0.9419 - val_loss: 0.3276 - val_accuracy: 0.8938
# Epoch 41/50
# 460/460 [==============================] - 23s 49ms/step - loss: 0.1084 - accuracy: 0.9520 - val_loss: 0.2846 - val_accuracy: 0.9260
# Epoch 42/50
# 460/460 [==============================] - 23s 49ms/step - loss: 0.1066 - accuracy: 0.9572 - val_loss: 0.2774 - val_accuracy: 0.9128
# Epoch 43/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1007 - accuracy: 0.9582 - val_loss: 0.2850 - val_accuracy: 0.9240
# Epoch 44/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1271 - accuracy: 0.9494 - val_loss: 0.3335 - val_accuracy: 0.9036
# Epoch 45/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1169 - accuracy: 0.9561 - val_loss: 0.2906 - val_accuracy: 0.9063
# Epoch 46/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1088 - accuracy: 0.9566 - val_loss: 0.3006 - val_accuracy: 0.9101
# Epoch 47/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1039 - accuracy: 0.9588 - val_loss: 0.3689 - val_accuracy: 0.9114
# Epoch 48/50
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1018 - accuracy: 0.9577 - val_loss: 0.3860 - val_accuracy: 0.9019
# Epoch 49/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1070 - accuracy: 0.9555 - val_loss: 0.3747 - val_accuracy: 0.9175
# Epoch 50/50
# 460/460 [==============================] - 22s 47ms/step - loss: 0.1074 - accuracy: 0.9574 - val_loss: 0.3073 - val_accuracy: 0.9172

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
